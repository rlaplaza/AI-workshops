# %% [markdown]
# ### Check package installations

# %%
import almos #https://almos.readthedocs.io/en/latest/

# %% [markdown]
# ### To see if ALMOS was properly installed:

# %%
# !python -m almos --help #https://almos.readthedocs.io/en/latest/

# %% [markdown]
# ### To see if EDBO+ was properly installed:

# %%
from edbo.optimizer_botorch import EDBOplus
print("EDBO imported correctly")
